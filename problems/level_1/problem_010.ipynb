# %% [markdown]
# <a href="https://colab.research.google.com/github/Akash-9794/numpy-100-challenges/blob/main/problems/level_1/problem_010.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Problem #010 Ready! 🔥
# Topic:  Level 1 Mixed Challenge!

# %% [markdown]
# #Problem #010

# %%
import numpy as np

# ─────────────────────────────────────────────
# FINAL BOSS — Level 1 Complete Challenge
# Uses EVERYTHING from Problems 001-009!
# ─────────────────────────────────────────────

# Challenge 1: Dataset Creation
# Hint: use random function + seed
# Create reproducible dataset:
# 1000 samples, 10 features, float32, seed=42

# Challenge 2: Inspect it fully
# Hint: use all 6 inspection attributes
# Print: shape, ndim, size, dtype, nbytes in KB, has NaN?

# Challenge 3: Create matching arrays
# Hint: zeros_like, ones_like
# Create zero matrix same shape as dataset
# Create ones matrix same shape as dataset
# Verify shapes match!

# Challenge 4: Memory comparison
# Hint: nbytes, astype
# Convert dataset to float64
# Compare memory: float32 vs float64
# Print: how many MB saved?

# Challenge 5: ML Pipeline! 🔥🔥
# Hint: randint, astype, full, eye
# a) Create 1000 labels (integers 0-9) → classification!
# b) Create 10x10 identity matrix → for one-hot encoding
# c) Create bias array of 64 neurons filled with 0.01
# d) Print shape and dtype of each

# %% [markdown]
# #Solution

# %%
import numpy as np

# ─────────────────────────────────────────────
# FINAL BOSS — Level 1 Complete Challenge
# Uses EVERYTHING from Problems 001-009!
# ─────────────────────────────────────────────

# Challenge 1: Dataset Creation
# Hint: use random function + seed
# Create reproducible dataset:
# 1000 samples, 10 features, float32, seed=42

np.random.seed(42)
sample_size = 1000
features = 10
arr = np.random.rand(sample_size,features).astype(np.float32)
# print(arr)



# Challenge 2: Inspect it fully
# Hint: use all 6 inspection attributes
# Print: shape, ndim, size, dtype, nbytes in KB, has NaN?

# print(arr.shape)
# print(arr.ndim)
# print(arr.size)
# print(arr.dtype)
# print(f"{arr.nbytes/1024} KB")
# print(np.isnan(arr).any())

# Challenge 3: Create matching arrays
# Hint: zeros_like, ones_like
# Create zero matrix same shape as dataset
# Create ones matrix same shape as dataset
# Verify shapes match!
np.random.seed(42)
zeros_arr = np.zeros_like(arr)   # pass your dataset
ones_arr  = np.ones_like(arr)    # pass your dataset

# Then verify:
print(arr.shape == zeros_arr.shape)  # should be True!

# Challenge 4: Memory comparison
# Hint: nbytes, astype
# Convert dataset to float64
# Compare memory: float32 vs float64
# Print: how many MB saved?

# Convert to float64
arr_f64 = arr.astype(np.float64)

# Compare memory
print(f"float32: {arr.nbytes/1024:.2f} KB")
print(f"float64: {arr_f64.nbytes/1024:.2f} KB")
print(f"Saved  : {(arr_f64.nbytes - arr.nbytes)/1024:.2f} KB")

# Challenge 5: ML Pipeline! 🔥🔥
# Hint: randint, astype, full, eye
# a) Create 1000 labels (integers 0-9) → classification!
# b) Create 10x10 identity matrix → for one-hot encoding
# c) Create bias array of 64 neurons filled with 0.01
# d) Print shape and dtype of each

labels = np.random.randint(0,10,1000)
identity = np.eye(10)
bias  = np.full((64,),0.01)
